# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import savemat,loadmat
import os
from jupyterthemes import jtplot

from matplotlib import pyplot
plt.style.use('seaborn-whitegrid')
palette = pyplot.get_cmap('Set1')
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 18,
}

# jtplot.style(theme='grade3') #选择一个绘图主题

result = {}
result['bci42a'] = {}
result['bci42a']['e'] = {}
result['bci42a']['d'] = {}
result['bci42a']['s'] = {}

result['p300'] = {}
result['p300']['e'] = {}
result['p300']['d'] = {}
result['p300']['s'] = {}

result['ern'] = {}
result['ern']['e'] = {}
result['ern']['d'] = {}
result['ern']['s'] = {}

# %% [markdown]
# ## Load result from files

# %% [markdown]
# BCI42A

# %%
ds = 'bci42a'
model = 'e'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/e/cv_white_none#03-09#11-56-12#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/e/cv_white_trades#03-09#12-06-54#5.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/e/cv_white_mart#03-09#12-07-07#1.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/e/cv_white_hbar#03-09#12-10-57#0.1-30.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/e/cv_white_hbar_adv#03-09#12-12-12#0.1-30.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/e/cv_white_adv#03-09#11-56-17#.mat'))

ds = 'bci42a'
model = 'd'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_none#03-09#18-52-05#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_trades#03-09#20-04-42#4.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_mart#03-09#21-45-08#4.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_hbar#03-09#18-51-40#0.1-30.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_hbar_adv#03-10#08-35-45#0.1-30.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_adv#03-09#18-51-32#.mat'))

ds = 'bci42a'
model = 's'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/s/cv_white_none#03-09#13-45-24#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/s/cv_white_trades#03-09#14-42-53#2.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/s/cv_white_mart#03-09#15-42-21#6.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/s/cv_white_hbar#03-09#14-59-20#0.1-30.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/s/cv_white_hbar_adv#03-09#18-55-38#0.1-30.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/s/cv_white_adv#03-09#13-45-41#.mat'))

# 调参请修改这里
# ds = 'bci42a'
# model = 'e'
# result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/d/cv_white_none#03-13#12-14-22#.mat'))
# result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__trades_0.5#02-27#11-12-34#2.mat'))
# result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_e_mart#03-08#17-27-01#1.mat'))
# result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__hbar_0.0#02-17#22-56-06#.mat'))
# result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.'),'output\\result\\bci42a\e\cv_white_vat#03-26#13-46-41_pa_#.mat'))
# result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__adv_1.0#02-18#11-08-31#.mat'))

# %% [markdown]
# P300

# %%
ds = 'p300'
model = 'e'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/e/cv_white_none#03-09#23-35-11#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/e/cv_white_trades#03-10#08-33-37#3.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/e/cv_white_mart#03-10#08-33-11#4.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/e/cv_white_hbar#03-10#08-41-42#0.1-5.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/e/cv_white_hbar_adv#03-11#22-21-45#0.01-0.05.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/e/cv_white_adv#03-10#08-32-05#.mat'))

ds = 'p300'
model = 'd'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/d/cv_white_none#03-10#08-40-37#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/d/cv_white_trades#03-10#18-50-23#4.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/d/cv_white_mart#03-10#23-58-32#4.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/d/cv_white_hbar#03-10#22-30-21#5-10.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/d/cv_white_hbar_adv#03-12#10-17-43#0.01-0.05.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/d/cv_white_adv#03-10#15-41-50#.mat'))

ds = 'p300'
model = 's'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/s/cv_white_none#03-09#23-36-15#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/s/cv_white_trades#03-10#08-43-41#6.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/s/cv_white_mart#03-10#15-36-26#4.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/s/cv_white_hbar#03-10#20-37-52#0.1-5.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/s/cv_white_hbar_adv#03-11#23-19-16#0.01-0.05.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/s/cv_white_adv#03-10#08-44-46#.mat'))

# 调参请修改这里
# ds = 'p300'
# model = 'e'
# result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__none_0.5#02-18#11-08-00#.mat'))
# result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__trades_0.5#02-27#11-12-34#2.mat'))
# result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'p300/cv_white_e_mart#03-08#19-34-37#1.mat'))
# result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__hbar_0.0#02-17#22-56-06#.mat'))
# result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__hbar_0.5#02-18#11-07-31#.mat'))
# result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__adv_1.0#02-18#11-08-31#.mat'))

# %% [markdown]
# ERN

# %%
ds = 'ern'
model = 'e'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_none#03-10#15-35-17#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_trades#03-11#15-25-21#4.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_mart#03-11#12-41-45#1.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_hbar#03-11#09-20-13#1-30.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_hbar_adv#03-12#10-16-02#0.01-0.05.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_adv#03-11#12-41-04#.mat'))

ds = 'ern'
model = 'd'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/d/cv_white_none#03-10#23-58-00#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/d/cv_white_trades#03-11#15-25-53#4.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/d/cv_white_mart#03-11#12-46-41#4.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/d/cv_white_hbar#03-11#12-42-28#5-10.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/d/cv_white_hbar_adv#03-12#10-16-47#0.01-0.05.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/d/cv_white_adv#03-11#00-03-21#.mat'))

ds = 'ern'
model = 's'
result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/s/cv_white_none#03-10#18-25-15#.mat'))
result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/s/cv_white_trades#03-11#22-17-21#1.mat'))
result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/s/cv_white_mart#03-11#12-45-50#9.mat'))
result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/s/cv_white_hbar#03-11#09-20-54#0.1-5.mat'))
result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/s/cv_white_hbar_adv#03-12#10-17-54#0.01-0.05.mat'))
result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/s/cv_white_adv#03-11#12-44-28#.mat'))

# 调参请修改这里
# ds = 'ern'
# model = 'e'
# result[ds][model]['ce']       = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__none_0.5#02-18#11-08-00#.mat'))
# result[ds][model]['trades']   = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/cv_white_e_trades#03-07#23-06-14#4_stage2.mat'))
# result[ds][model]['mart']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/cv_white_e_mart#03-07#23-05-36#1_stage2.mat'))
# result[ds][model]['hbar']     = loadmat(os.path.join(os.path.abspath('.\output\\result'),'bci42a/cv_white_s__hbar_0.0#02-17#22-56-06#.mat'))
# result[ds][model]['hbar_adv'] = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/e/cv_white_hbar_adv#03-12#17-00-58#0.1-5.mat'))
# result[ds][model]['adv']      = loadmat(os.path.join(os.path.abspath('.\output\\result'),'ern/cv_white_e_adv#03-08#08-36-31#stage2.mat'))

# %% [markdown]
# ## Detailed drawing

# %%
start_sub = 0
end_sub = 12 # 9, 8, 12

atk_list = ['FGSM', 'TLM-UAP', 'SAP']
ds_ = ['bci42a', 'p300', 'ern']
model_ = ['e', 's', 'd']

# ds_ = ['bci42a']
model_ = ['e']
marker = ['o', 'v', '^', '*', 'd', '$\\bigcirc$']
markersize = [11, 15, 15, 18, 15, 15]
markersize = [23, 30, 30, 35, 30, 30]
for ds in ds_:
    for model in model_:
        print('-------------')
        print(ds, model)

        x = result[ds][model]['ce']['epsilon'][0]
        step = len(x)
        x = np.append([0],x)

        for index in range(3):  
            start_atk = step*index + 1
            end_atk = step*(index+1) + 1

            mask = [0]
            acc1 = np.concatenate((result[ds][model]['ce']['acc'][start_sub:end_sub,:,0:1], result[ds][model]['ce']['acc'][start_sub:end_sub,:,start_atk:end_atk]), axis=2) 
            acc2 = np.concatenate((result[ds][model]['trades']['acc'][start_sub:end_sub,:,0:1], result[ds][model]['trades']['acc'][start_sub:end_sub,:,start_atk:end_atk]), axis=2)
            acc3 = np.concatenate((result[ds][model]['mart']['acc'][start_sub:end_sub,:,0:1], result[ds][model]['mart']['acc'][start_sub:end_sub,:,start_atk:end_atk]), axis=2)
            acc4 = np.concatenate((result[ds][model]['hbar']['acc'][start_sub:end_sub, mask, 0:1], result[ds][model]['hbar']['acc'][start_sub:end_sub, mask, start_atk:end_atk]), axis=2)
            acc5 = np.concatenate((result[ds][model]['hbar_adv']['acc'][start_sub:end_sub, mask, 0:1], result[ds][model]['hbar_adv']['acc'][start_sub:end_sub, mask, start_atk:end_atk]), axis=2)
            acc6 = np.concatenate((result[ds][model]['adv']['acc'][start_sub:end_sub, mask, 0:1], result[ds][model]['adv']['acc'][start_sub:end_sub, mask, start_atk:end_atk]), axis=2)
            acc = np.concatenate((acc1, acc2, acc3, acc4, acc5, acc6),axis=1)
            beta = ['Natural', 'TRADES', 'MART', 'HBaR', 'HBaR+PGD', 'PGD']

            acc = np.mean(acc, axis=0)

            plt.figure(figsize=(10, 6.6))
            # plt.figure(figsize=(30, 18))
            # plt.title('White Box Attack, '+ds+', '+model+', '+atk_list[index], fontsize=16)
            for i in range(acc.shape[0]):
                
                y = acc[i,:]
                # print(ds, model, atk_list[index], beta[i], y[-1])

                color=palette(i)#算法1颜色
                avg=np.mean(y, axis=-1)
                std=np.std(y, axis=-1)
                
                r1 = list(map(lambda x: x[0]-x[1], zip(avg, std)))#上方差
                r2 = list(map(lambda x: x[0]+x[1], zip(avg, std)))#下方差
                
                if i == 5:
                    color = 'c'
                plt.plot(x, avg, color=color,label=str(beta[i]),linewidth=6.0,linestyle='-',marker = marker[i], markersize = markersize[i])

                # plt.fill_between(x, r1, r2, color=color, alpha=0.2)

            if model == 'e':
                my_y_ticks = np.arange(0, 0.8, 0.15)
                plt.yticks(my_y_ticks)
                plt.ylim((-0.05, 0.75))
            else:
                my_y_ticks = np.arange(0, 0.9, 0.15)
                plt.yticks(my_y_ticks)
                plt.ylim((-0.05, 0.85))
            if ds == 'p300':
                my_x_ticks = np.arange(0, 0.155, 0.03)
                plt.xticks(my_x_ticks)
                plt.xlim((-0.005, 0.155))
            if ds == 'bci42a':
                my_x_ticks = np.arange(0, 0.0035, 0.001)
                plt.xticks(my_x_ticks)
                plt.xlim((-0.0001, 0.0031))

            ax = plt.gca()#获取边框
            bwith = 4
            ax.spines['top'].set_visible(True)
            ax.spines['right'].set_visible(True)
            ax.spines['bottom'].set_visible(True)
            ax.spines['left'].set_visible(True)
            ax.spines['top'].set_linewidth(bwith)
            ax.spines['right'].set_linewidth(bwith)
            ax.spines['bottom'].set_linewidth(bwith)
            ax.spines['left'].set_linewidth(bwith)
            ax.spines['top'].set_color('black') 
            ax.spines['right'].set_color('black')
            ax.spines['bottom'].set_color('black') 
            ax.spines['left'].set_color('black') 
            ax.grid(False)

            # plt.legend(ncol=3,frameon=True) 
            # plt.rc('legend', fontsize=46)
            plt.xlabel('Pertubation, $\epsilon$',fontsize=36)
            plt.ylabel('Accuracy',fontsize=36)
            # plt.tick_params(axis='both',direction='in', width=2.5, length=8, labelsize=18, top=True, right= True)
            plt.tick_params(axis='both',direction='in', width=3, length=10, labelsize=36, top=True, right= True)
            save_path = os.path.join(os.path.abspath(''), 'output/figure/', ds+'_'+model+'_'+atk_list[index]+'.png')
            plt.savefig(save_path, dpi=600, format='png') # 解决图片不清晰，不完整的问题
    plt.show()
# Out:
# -------------
# bci42a e
# -------------
# p300 e
# -------------
# ern e

# %% [markdown]
# ## Comparison of model robustness

# %%
start_sub = 0
end_sub = 12
mask = [0]

ds_ = ['bci42a', 'ern', 'p300']
marker = ['s', '$\\bigcirc$', '^', '*', 'd', '$\\bigcirc$']
markersize = [25, 30, 30, 18, 15, 15]
# ds_ = ['bci42a']
# model_ = ['e']
xlabel = ['MI, Pertubation $\epsilon$', 'ERN, Pertubation $\epsilon$', 'P300, Pertubation $\epsilon$']
j = 0
for ds in ds_:
    acc1 = result[ds]['e']['ce']['acc'][start_sub:end_sub,]
    acc2 = result[ds]['s']['ce']['acc'][start_sub:end_sub,]
    acc3 = result[ds]['d']['ce']['acc'][start_sub:end_sub,]
    acc = np.concatenate((acc1, acc2, acc3),axis=1)
    beta = ['EEGNet', 'ShllowCNN', 'DeepCNN']

    acc = np.mean(acc, axis=0)
    x = result[ds][model]['ce']['epsilon'][0]
    step = len(x)

    acc_natural = acc[:,:1,:]
    acc = (acc[:,1:step+1] + acc[:,step+1:2*step+1]+acc[:,2*step+1:])/3.
    # acc = (acc[:,1:step+1] + acc[:,2*step+1:])/2.
    acc = np.concatenate((acc_natural, acc), axis=1)

    x = np.append([0],x)
    plt.figure(figsize=(12, 9))
    plt.figure(figsize=(10, 6.6))
    # plt.title('White Box Attack ' + ds + ' model robust' , fontsize=16)
    for i in range(acc.shape[0]):
        y = acc[i,:]
        
        color=palette(i)#算法1颜色
        # if i == 2:
        #     color = palette(3)

        avg=np.mean(y, axis=-1)
        std=np.std(y, axis=-1)
        r1 = list(map(lambda x: x[0]-x[1], zip(avg, std)))#上方差
        r2 = list(map(lambda x: x[0]+x[1], zip(avg, std)))#下方差

        plt.plot(x, avg, color=color,label=str(beta[i]),linewidth=8.0,linestyle='-',marker = marker[i], markersize = markersize[i])
        
        # plt.fill_between(x, r1, r2, color=color, alpha=0.2)

    ax = plt.gca()#获取边框
    bwith = 4
    ax.spines['top'].set_visible(True)
    ax.spines['right'].set_visible(True)
    ax.spines['bottom'].set_visible(True)
    ax.spines['left'].set_visible(True)
    ax.spines['top'].set_linewidth(bwith)
    ax.spines['right'].set_linewidth(bwith)
    ax.spines['bottom'].set_linewidth(bwith)
    ax.spines['left'].set_linewidth(bwith)
    ax.spines['top'].set_color('black') 
    ax.spines['right'].set_color('black')
    ax.spines['bottom'].set_color('black') 
    ax.spines['left'].set_color('black') 
    ax.grid(False)

    my_y_ticks = np.arange(0.2, 0.85, 0.2)
    plt.yticks(my_y_ticks)
    plt.ylim((0, 0.8))

    plt.legend() 
    plt.rc('legend', fontsize=46)

    
    plt.ylabel('Accuracy',fontsize=36)

    
    plt.xlabel('Pertubation $\epsilon$',fontsize=36)
    j = j+1
    
    plt.tick_params(axis='both',direction='in', width=3, length=10, labelsize=36, top=True, right= True)
    save_path = os.path.join(os.path.abspath(''), 'output/figure/', ds+'_model_robust.png')
    plt.savefig(save_path, dpi=600, format='png') # 解决图片不清晰，不完整的问题
    plt.show()

# %% [markdown]
# ## Adversarial examples visualization

# %%
fgsm_adv_ex = loadmat('output/result/fgsmadv.mat')
sap_adv_ex = loadmat('output/result/sapadv.mat')
uap_adv_ex = loadmat('output/result/uapadv.mat')

s = 500
e = s+250

adv_examples_ = []

adv_ = fgsm_adv_ex['adv'][0,0,7]
raw_ = fgsm_adv_ex['benign'][0,0,7]

adv_examples_.append(raw_[s:e])
adv_examples_.append(adv_[s:e])

adv_ = uap_adv_ex['adv'][0,0,7]
adv_examples_.append(adv_[s:e])

adv_ = sap_adv_ex['adv'][0,0,7]
raw_ = sap_adv_ex['benign'][0,0,7]

adv_examples_.append(adv_[s:e])

print(len(adv_examples_))
# Out:
# 4

# %%
from jupyterthemes import jtplot
jtplot.style(theme='grade3') #选择一个绘图主题
from matplotlib import pyplot
palette = pyplot.get_cmap('Set1')
plt.style.use('seaborn-whitegrid')
adv_examples = adv_examples_
step = -0.3
diff_step = -0.03
x_ticks = np.arange(0, adv_examples[0].shape[-1]/250, 1/250)

ch_idx = [7,7,7]
y_labels = ['UFGSM', 'TLM-UAP', 'SAP']

plt.figure(figsize=(10, 6.6))
X_raw = adv_examples[0]
for i in range(3):
    X_adv = adv_examples[i+1]
    X_diff = X_raw-X_adv

    X_raw = X_raw - np.mean(X_raw)
    X_adv = X_adv - np.mean(X_adv)

    if i == 0:
        plt.plot(x_ticks, X_adv + step*i, label = 'adversarial example', color=palette(0), linewidth=3.0)
        plt.plot(x_ticks, X_raw + step*i, label = 'natural example', color=palette(1), linewidth=3.0)
    else:
        plt.plot(x_ticks, X_adv + step*i, color=palette(0), linewidth=3.0)
        plt.plot(x_ticks, X_raw + step*i, color=palette(1), linewidth=3.0)


ax = plt.gca()#获取边框
bwith = 3
ax.spines['top'].set_visible(True)
ax.spines['right'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['top'].set_linewidth(bwith)
ax.spines['right'].set_linewidth(bwith)
ax.spines['bottom'].set_linewidth(bwith)
ax.spines['left'].set_linewidth(bwith)
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['bottom'].set_color('black') 
ax.spines['left'].set_color('black') 
ax.grid(False)

my_x_ticks = np.arange(0, 1.5, 0.5)
plt.xticks(my_x_ticks)
plt.xlim((-0.1, 1.1))

plt.yticks([step*index for index in range(len(ch_idx))], y_labels, rotation=90)


plt.rc('legend', fontsize=22)
plt.legend(ncol=2,frameon=True)

plt.xlabel('Time(s)',fontsize=22)
plt.ylabel('Attack Method',fontsize=22)


# plt.tick_params(axis='both',direction='out', width=1.5, length=6, labelsize=18)
plt.tick_params(axis='both',direction='in', width=2.5, length=7, labelsize=20, top=True, right= True)
plt.savefig('output/figure/adv.png', dpi=600, transparent = False) # 解决图片不清晰，不完整的问题
plt.savefig('output/figure/adv.eps', dpi=600, format='eps') # 解决图片不清晰，不完整的问题


plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
from jupyterthemes import jtplot
jtplot.style(theme='grade3') #选择一个绘图主题
from matplotlib import pyplot
palette = pyplot.get_cmap('Set1')
plt.style.use('seaborn-whitegrid')
adv_examples = adv_examples_
step = -0.03
x_ticks = np.arange(0, adv_examples[0].shape[-1]/250, 1/250)

ch_idx = [7,7,7]
y_labels = ['UFGSM', 'TLM-UAP', 'SAP']

plt.figure(figsize=(10, 6.6))
X_raw = adv_examples[0]
for i in range(3):
    X_adv = adv_examples[i+1]
    X_diff = X_raw-X_adv

    X_raw = X_raw - np.mean(X_raw)
    X_adv = X_adv - np.mean(X_adv)
    X_diff = X_raw - X_adv

    plt.plot(x_ticks, X_diff + step*i, color=palette(0), linewidth=3.0)

ax = plt.gca()#获取边框
bwith = 3
ax.spines['top'].set_visible(True)
ax.spines['right'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['top'].set_linewidth(bwith)
ax.spines['right'].set_linewidth(bwith)
ax.spines['bottom'].set_linewidth(bwith)
ax.spines['left'].set_linewidth(bwith)
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['bottom'].set_color('black') 
ax.spines['left'].set_color('black') 
ax.grid(False)

my_x_ticks = np.arange(0, 1.5, 0.5)
plt.xticks(my_x_ticks)
plt.xlim((-0.1, 1.1))
plt.ylim((-0.003+2*step-0.0175, 0.003+0.0125))
plt.yticks([step*index for index in range(len(ch_idx))], y_labels, rotation=90)


# plt.rc('legend', fontsize=16)
# plt.legend(ncol=2,frameon=True)

plt.xlabel('Time(s)',fontsize=22)
plt.ylabel('Attack Method',fontsize=22)


# plt.tick_params(axis='both',direction='out', width=1.5, length=6, labelsize=18)
plt.tick_params(axis='both',direction='in', width=2.5, length=7, labelsize=20, top=True, right= True)
plt.savefig('output/figure/adv_diff.png', dpi=600, transparent = False) # 解决图片不清晰，不完整的问题
plt.savefig('output/figure/adv_diff.eps', dpi=600, format='eps') # 解决图片不清晰，不完整的问题


plt.show()
